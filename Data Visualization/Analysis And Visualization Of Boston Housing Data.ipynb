# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pickle as pkl

# %% [markdown]
# ### Data Loading

# %%
boston = pkl.load(open('D:/Data Science/Data Visualization/DataVisualization/Boston EDA/boston_housing.pkl','rb'))

# %%
type(boston)
# Out:
# sklearn.utils.Bunch

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
df = pd.DataFrame(data=boston.data,columns=boston.feature_names)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df['Price'] = boston.target

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %% [markdown]
# ### Data Preparation

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data_descr = df.describe().T
data_descr['mean']
# Out:
# CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# Price       22.532806
# Name: mean, dtype: float64

# %%
data_descr['mean'].plot.bar()
plt.show()

# %%
for style in plt.style.available :
    plt.style.use(style)
    data_descr['mean'].plot.bar()
    plt.savefig('D:/Data Science/Data Visualization/Styles/'+style+'.png')

# %%
plt.style.use('ggplot')

# %%
import seaborn as sns
sns.pairplot(df.iloc[:,np.hstack(([0],range(7,14)))],diag_kind='kde')

# %%
rows=2
cols=7
fig,ax = plt.subplots(nrows=rows,ncols=cols,figsize=(16,4))

col = df.columns
index=0
for i in range(rows):
    for j in range(cols):
        sns.distplot(df[col[index]],ax= ax[i][j])
        index=index+1
plt.tight_layout()
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\ANACONDA\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\ANACONDA\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
rows=2
cols=7
fig,ax = plt.subplots(nrows=rows,ncols=cols,figsize=(16,4))

col = df.columns
index=0
for i in range(rows):
    for j in range(cols):
        sns.scatterplot(x='Price',y=col[index],data=df,ax= ax[i][j])
        index=index+1
plt.tight_layout()

# %%
corrmat = df.corr()
sns.heatmap(corrmat,annot=True)
# Out:
# <AxesSubplot:>

# %%
def getCorrelatedfeature(corrdata,threshold):
    value = []
    feature = []
    
    for i,index in enumerate(corrdata.index):
        if(abs(corrdata[index])) > threshold :
            feature.append(index)
            value.append(corrdata[index])
    
    df = pd.DataFrame(data=value,index=feature,columns=['corr value'])
    
    return df

# %%
threshold = 0.5
result = getCorrelatedfeature(corrmat['Price'],threshold)

# %%
result
# Out:
#          corr value
# RM         0.695360
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Price      1.000000

# %%
abs(corrmat['Price'])
# Out:
# CRIM       0.388305
# ZN         0.360445
# INDUS      0.483725
# CHAS       0.175260
# NOX        0.427321
# RM         0.695360
# AGE        0.376955
# DIS        0.249929
# RAD        0.381626
# TAX        0.468536
# PTRATIO    0.507787
# B          0.333461
# LSTAT      0.737663
# Price      1.000000
# Name: Price, dtype: float64

# %%
result.index
# Out:
# Index(['RM', 'PTRATIO', 'LSTAT', 'Price'], dtype='object')

# %%
df_correlated = df[result.index]

# %% [markdown]
# ### pairplot()

# %%
sns.pairplot(df_correlated)
plt.show()

# %% [markdown]
# ### heatmap() for most correlated Features

# %%
sns.heatmap(df_correlated.corr(),annot=True,annot_kws={'size':14})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### boxplot() and relplot()

# %%
sns.boxplot(x='CHAS',y='Price',data=df)
# Out:
# <AxesSubplot:xlabel='CHAS', ylabel='Price'>

# %%
sns.relplot(x='RM',y='Price',data=df,hue='CHAS',col='CHAS')

# %% [markdown]
# ### jointplot() to find Distribution of variables and relation in one plot

# %%
sns.jointplot(x='RM',y='Price',data=df,kind='hex')
plt.show()

# %%
sns.jointplot(x='RM',y='Price',data=df,hue='CHAS')
plt.show()

# %% [markdown]
# ### regplot() and lmplot() to understand Correlation more Precisely

# %%
sns.regplot(x='RM',y='Price',data=df)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='Price'>

# %%
sns.lmplot(x='RM',y='Price',data=df,hue='CHAS',col='CHAS')
plt.show()

# %%
sns.lmplot(x='RM',y='Price',data=df,col='CHAS',order=2)
