# %% [markdown]
# ### Line Plot

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn,randint,uniform,sample

# %%
df = pd.DataFrame(randn(1000),index=pd.date_range('2021-11-28',periods=1000),columns=['values'])

# %%
df
# Out:
#               values
# 2021-11-28  1.279793
# 2021-11-29  0.022178
# 2021-11-30  0.425539
# 2021-12-01  0.319359
# 2021-12-02  0.038632
# ...              ...
# 2024-08-19  0.794695
# 2024-08-20 -0.332986
# 2024-08-21  0.710202
# 2024-08-22 -1.403800
# 2024-08-23  0.444693
#
# [1000 rows x 1 columns]

# %%
ts = pd.Series(randn(1000),index=pd.date_range('2021-11-28',periods=1000))

# %%
ts
# Out:
# 2021-11-28    0.366183
# 2021-11-29   -0.584973
# 2021-11-30    0.365493
# 2021-12-01   -0.588256
# 2021-12-02    1.734378
#                 ...
# 2024-08-19   -0.425159
# 2024-08-20    1.447430
# 2024-08-21   -0.607984
# 2024-08-22    0.935824
# 2024-08-23   -0.557241
# Freq: D, Length: 1000, dtype: float64

# %%
df['values'] = df['values'].cumsum()
df.head()
# Out:
#               values
# 2021-11-28  1.279793
# 2021-11-29  1.301972
# 2021-11-30  1.727510
# 2021-12-01  2.046869
# 2021-12-02  2.085501

# %%
df.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
ts = ts.cumsum()

# %%
ts.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
iris.plot(legend= False,figsize=(10,5),logy=True)
# Out:
# <AxesSubplot:>

# %%
x = iris.drop(columns=['sepal_width','petal_width'])

# %%
x.head()
# Out:
#    sepal_length  petal_length species
# 0           5.1           1.4  setosa
# 1           4.9           1.4  setosa
# 2           4.7           1.3  setosa
# 3           4.6           1.5  setosa
# 4           5.0           1.4  setosa

# %%
y = iris[['sepal_width','petal_width']]

# %%
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize=(16,10),secondary_y=True,ax=ax)
# Out:
# <AxesSubplot:label='d8329a69-60d6-4552-8d18-67f695c3e728'>

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic['pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic['pclass'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0  1.281007  0.151151  0.171608 -1.260947
# 1  2.006400 -0.370216  0.186993 -0.862924
# 2 -0.417454 -1.392091  0.367339  1.046558
# 3 -1.540663  1.205690 -1.098919 -0.403429
# 4 -0.568920 -0.009435 -0.752693 -1.098482

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
### Histogram
iris.plot(kind = 'hist',bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',bins= 30,stacked=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',bins=30,stacked=True,orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df = iris.drop(['species'],axis=1)
df.diff().hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df = iris.drop(['species'],axis=1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
### Box Plot

df.plot(kind = 'box',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'box',figsize=(10,5),vert=False)
# Out:
# <AxesSubplot:>

# %%
## Area and Scatter Plot

df.plot(kind='area',stacked=False,figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',stacked=False,figsize=(10,5),alpha=0.9)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='scatter',x='petal_width',y='sepal_width',c='sepal_length')
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>

# %%
ax = df.plot(kind='scatter',x='petal_width',y='sepal_width')
df.plot(kind ='scatter',x='petal_length',y='sepal_length',ax=ax,c='r')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>

# %%
df.plot(kind = 'hexbin',x='petal_width',y='sepal_width',gridsize=20,C = 'sepal_length')
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>

# %%
df.iloc[6].plot.pie()
# Out:
# <AxesSubplot:ylabel='6'>

# %%
d = df.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot(subplots=True,kind='pie',figsize=(50,50),fontsize=24,autopct='%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
### Scatter_Matrix and Subplots

from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(20,20),diagonal='kde',color='r')
plt.show()

# %%
df.plot(subplots=True,sharex=False)
plt.tight_layout()
plt.show()

# %%
df.plot(subplots=True,sharex=False,figsize=(6,6),layout=(2,2))
plt.tight_layout()
plt.show()
